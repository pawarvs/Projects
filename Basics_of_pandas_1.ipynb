# %% [markdown]
# ## Pandas Library

# %%
# importing pandas library 
import pandas as pd
import warnings
  

warnings.filterwarnings('ignore')

# %%
# reading excel file in jupyter notebook,
df = pd.read_excel("D:\SQL\mysql Course assets\Projects\IPL_Ball.xlsx")

# DataFrame.head() function will gives first 5 records of dataset by default
df.head()
# Out:
#        id  inning  over  ball      batsman  non_striker   bowler  \
# 0  335982       1     0     1   SC Ganguly  BB McCullum  P Kumar
# 1  335982       1     0     2  BB McCullum   SC Ganguly  P Kumar
# 2  335982       1     0     3  BB McCullum   SC Ganguly  P Kumar
# 3  335982       1     0     4  BB McCullum   SC Ganguly  P Kumar
# 4  335982       1     0     5  BB McCullum   SC Ganguly  P Kumar
#
#    batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# 0             0           1           1          0            NaN
# 1             0           0           0          0            NaN
# 2             0           1           1          0            NaN
# 3             0           0           0          0            NaN
# 4             0           0           0          0            NaN
#
#   player_dismissed fielder extras_type           batting_team  \
# 0              NaN     NaN     legbyes  Kolkata Knight Riders
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (193468, 17)

# %%
# If datafile has more than 1 sheet, to read perticular sheet of the datafile, we pass sheet_name.
pd.read_excel("D:\SQL\mysql Course assets\Projects\IPL_Ball.xlsx",sheet_name = 'Sample')
# Out:
#         id        city        date player_of_match  \
# 0   335982   Bangalore  18-04-2008     BB McCullum
# 1   335983  Chandigarh  19-04-2008      MEK Hussey
# 2   335984       Delhi  19-04-2008     MF Maharoof
# 3   335985      Mumbai  20-04-2008      MV Boucher
# 4   335986     Kolkata  20-04-2008       DJ Hussey
# 5   335987      Jaipur  21-04-2008       SR Watson
# 6   335988   Hyderabad  22-04-2008        V Sehwag
# 7   335989     Chennai  23-04-2008       ML Hayden
# 8   335990   Hyderabad  24-04-2008       YK Pathan
# 9   335991  Chandigarh  25-04-2008   KC Sangakkara
# 10  335992   Bangalore  26-04-2008       SR Watson
# 11  335993     Chennai  26-04-2008        JDP Oram
# 12  335994      Mumbai  27-04-2008    AC Gilchrist
# 13  335995  Chandigarh  27-04-2008       SM Katich
#
#                                          venue
# 0                        M Chinnaswamy Stadium
# 1   Punjab Cricket Association Stadium, Mohali
# 2                             Feroz Shah Kotla
# ...

# %%
# If you don't want the column headers

pd.read_excel("D:\SQL\mysql Course assets\Projects\IPL_Ball.xlsx",sheet_name = 'Sample',header = None)
# Out:
#          0           1           2                3  \
# 0       id        city        date  player_of_match
# 1   335982   Bangalore  18-04-2008      BB McCullum
# 2   335983  Chandigarh  19-04-2008       MEK Hussey
# 3   335984       Delhi  19-04-2008      MF Maharoof
# 4   335985      Mumbai  20-04-2008       MV Boucher
# 5   335986     Kolkata  20-04-2008        DJ Hussey
# 6   335987      Jaipur  21-04-2008        SR Watson
# 7   335988   Hyderabad  22-04-2008         V Sehwag
# 8   335989     Chennai  23-04-2008        ML Hayden
# 9   335990   Hyderabad  24-04-2008        YK Pathan
# 10  335991  Chandigarh  25-04-2008    KC Sangakkara
# 11  335992   Bangalore  26-04-2008        SR Watson
# 12  335993     Chennai  26-04-2008         JDP Oram
# 13  335994      Mumbai  27-04-2008     AC Gilchrist
# 14  335995  Chandigarh  27-04-2008        SM Katich
#
#                                              4
# 0                                        venue
# ...

# %%
# If you have to give header names of your choice
pd.read_excel("D:\SQL\mysql Course assets\Projects\IPL_Ball.xlsx",sheet_name = 'Sample',header = None, names = [ "Id","City","Date","Player_of_Match","Venue"] )
# Out:
#         Id        City        Date  Player_of_Match  \
# 0       id        city        date  player_of_match
# 1   335982   Bangalore  18-04-2008      BB McCullum
# 2   335983  Chandigarh  19-04-2008       MEK Hussey
# 3   335984       Delhi  19-04-2008      MF Maharoof
# 4   335985      Mumbai  20-04-2008       MV Boucher
# 5   335986     Kolkata  20-04-2008        DJ Hussey
# 6   335987      Jaipur  21-04-2008        SR Watson
# 7   335988   Hyderabad  22-04-2008         V Sehwag
# 8   335989     Chennai  23-04-2008        ML Hayden
# 9   335990   Hyderabad  24-04-2008        YK Pathan
# 10  335991  Chandigarh  25-04-2008    KC Sangakkara
# 11  335992   Bangalore  26-04-2008        SR Watson
# 12  335993     Chennai  26-04-2008         JDP Oram
# 13  335994      Mumbai  27-04-2008     AC Gilchrist
# 14  335995  Chandigarh  27-04-2008        SM Katich
#
#                                          Venue
# 0                                        venue
# ...

# %%
# DataFrame.head() function will gives number of records we want to see. the number we will pass only those records you are able to see.
df.head(2)
# Out:
#        id  inning  over  ball      batsman  non_striker   bowler  \
# 0  335982       1     0     1   SC Ganguly  BB McCullum  P Kumar
# 1  335982       1     0     2  BB McCullum   SC Ganguly  P Kumar
#
#    batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# 0             0           1           1          0            NaN
# 1             0           0           0          0            NaN
#
#   player_dismissed fielder extras_type           batting_team  \
# 0              NaN     NaN     legbyes  Kolkata Knight Riders
# 1              NaN     NaN         NaN  Kolkata Knight Riders
#
#                   bowling_team
# 0  Royal Challengers Bangalore
# 1  Royal Challengers Bangalore

# %%
# DataFrame.tail() function will read tail values of dataset.
df.tail(2)
# Out:
#              id  inning  over  ball    batsman   non_striker    bowler  \
# 193466  1237181       2    18     3  HH Pandya  Ishan Kishan  A Nortje
# 193467  1237181       2    18     4  KH Pandya  Ishan Kishan  A Nortje
#
#         batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# 193466             0           0           0          1         caught
# 193467             1           0           1          0            NaN
#
#        player_dismissed    fielder extras_type    batting_team    bowling_team
# 193466        HH Pandya  AM Rahane         NaN  Mumbai Indians  Delhi Capitals
# 193467              NaN        NaN         NaN  Mumbai Indians  Delhi Capitals

# %%
df.tail()
# Out:
#              id  inning  over  ball       batsman   non_striker    bowler  \
# 193463  1237181       2    17     6     HH Pandya  Ishan Kishan  K Rabada
# 193464  1237181       2    18     1     HH Pandya  Ishan Kishan  A Nortje
# 193465  1237181       2    18     2  Ishan Kishan     HH Pandya  A Nortje
# 193466  1237181       2    18     3     HH Pandya  Ishan Kishan  A Nortje
# 193467  1237181       2    18     4     KH Pandya  Ishan Kishan  A Nortje
#
#         batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# 193463             1           0           1          0            NaN
# 193464             1           0           1          0            NaN
# 193465             1           0           1          0            NaN
# 193466             0           0           0          1         caught
# 193467             1           0           1          0            NaN
#
#        player_dismissed    fielder extras_type    batting_team    bowling_team
# ...

# %%
# To read csv file in the jupyter notebook
data = pd.read_csv("D:\Power Bi\Datasets\HRDataset_v14.csv")
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
pd.read_csv("D:\Book1.csv")
# Out:
#     a@b@c
# 0  1@9@10
# 1  2@7@20
# 2  3@6@30
# 3   6@4@6
# 4  5@5@15
# 5   4@2@9

# %%
# If you don't want the delimeter already present in the dataset, use sep = ' ' , pass that perticular delimeter in inverted commas.
pd.read_csv("D:\Book1.csv",sep = '@')
# Out:
#    a  b   c
# 0  1  9  10
# 1  2  7  20
# 2  3  6  30
# 3  6  4   6
# 4  5  5  15
# 5  4  2   9

# %%
# To read the dataset of the github reposatory.
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv')
# Out:
#            date  values.I2P  values.P2I  values.JPI
# 0    1996-04-01   -2.580556   -0.836444        63.3
# 1    1996-05-01   -2.882258   -1.972581        66.3
# 2    1996-06-01   -1.742778   -0.478778        59.7
# 3    1996-07-01   -0.397796   -1.574301        63.3
# 4    1996-08-01   -0.977151   -1.797312        63.8
# ..          ...         ...         ...         ...
# 112  2005-08-01   -2.144935   -1.646989        49.0
# 113  2005-09-01   -3.543270   -1.769889        49.9
# 114  2005-10-01   -4.500484   -2.309946        50.6
# 115  2005-11-01   -4.098556   -1.528611        57.4
# 116  2005-12-01   -5.797043   -2.872849        52.9
#
# [117 rows x 4 columns]

# %%
# To read html file in the jupyter notebook
a = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
a
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# Type of the html file is list, 
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %% [markdown]
# Json file

# %%
js = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
js.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['url'][0]
# Out:
# 'https://api.github.com/repos/pandas-dev/pandas/issues/48281'

# %%
js['user'][0]
# Out:
# {'login': 'ambujpawar',
#  'id': 19887541,
#  'node_id': 'MDQ6VXNlcjE5ODg3NTQx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/19887541?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/ambujpawar',
#  'html_url': 'https://github.com/ambujpawar',
#  'followers_url': 'https://api.github.com/users/ambujpawar/followers',
#  'following_url': 'https://api.github.com/users/ambujpawar/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/ambujpawar/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/ambujpawar/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/ambujpawar/subscriptions',
#  'organizations_url': 'https://api.github.com/users/ambujpawar/orgs',
#  'repos_url': 'https://api.github.com/users/ambujpawar/repos',
#  'events_url': 'https://api.github.com/users/ambujpawar/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/ambujpawar/received_events',
#  'type': 'User',
# ...

# %%
df
# Out:
#              id  inning  over  ball       batsman   non_striker    bowler  \
# 0        335982       1     0     1    SC Ganguly   BB McCullum   P Kumar
# 1        335982       1     0     2   BB McCullum    SC Ganguly   P Kumar
# 2        335982       1     0     3   BB McCullum    SC Ganguly   P Kumar
# 3        335982       1     0     4   BB McCullum    SC Ganguly   P Kumar
# 4        335982       1     0     5   BB McCullum    SC Ganguly   P Kumar
# ...         ...     ...   ...   ...           ...           ...       ...
# 193463  1237181       2    17     6     HH Pandya  Ishan Kishan  K Rabada
# 193464  1237181       2    18     1     HH Pandya  Ishan Kishan  A Nortje
# 193465  1237181       2    18     2  Ishan Kishan     HH Pandya  A Nortje
# 193466  1237181       2    18     3     HH Pandya  Ishan Kishan  A Nortje
# 193467  1237181       2    18     4     KH Pandya  Ishan Kishan  A Nortje
#
#         batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# ...

# %%
# To convert excel file to Json file
df.to_json('excel_to_json')

# %%
pwd
# Out:
# 'D:\\Ineuron learning'

# %%
# To read json file
pd.read_json('excel_to_json')
# Out:
#              id  inning  over  ball       batsman   non_striker    bowler  \
# 0        335982       1     0     1    SC Ganguly   BB McCullum   P Kumar
# 1        335982       1     0     2   BB McCullum    SC Ganguly   P Kumar
# 2        335982       1     0     3   BB McCullum    SC Ganguly   P Kumar
# 3        335982       1     0     4   BB McCullum    SC Ganguly   P Kumar
# 4        335982       1     0     5   BB McCullum    SC Ganguly   P Kumar
# ...         ...     ...   ...   ...           ...           ...       ...
# 193463  1237181       2    17     6     HH Pandya  Ishan Kishan  K Rabada
# 193464  1237181       2    18     1     HH Pandya  Ishan Kishan  A Nortje
# 193465  1237181       2    18     2  Ishan Kishan     HH Pandya  A Nortje
# 193466  1237181       2    18     3     HH Pandya  Ishan Kishan  A Nortje
# 193467  1237181       2    18     4     KH Pandya  Ishan Kishan  A Nortje
#
#         batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# ...

# %%
df.to_csv("D:\\Ipl_test",index = False)

# %% [raw]
# Mysql :
#
# 1. Create a table for Ipl_Ball and Ipl matches dataset.
# 2. Do a bulk load for Ipl_Ball ans IpL_mathces tables.
# 3. Read these dataset in pandas as dataframe.
# 4. Convert Ipl_ball dataset to json format.
# 5. Store this dataset into mongodb
# 6. in Sql task try to perform left join operation.
# 7.

# %%
data = pd.read_csv("D:\Power Bi\Datasets\HRDataset_v14.csv")

# %%
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
# To find the columns present in the dataset
df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
# slicing operation
df['batsman'].head()
# Out:
# 0     SC Ganguly
# 1    BB McCullum
# 2    BB McCullum
# 3    BB McCullum
# 4    BB McCullum
# Name: batsman, dtype: object

# %%
# Type of the column of the dataframe is series ( similar to list)
type(df['batsman'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ###### DataFrame.info() function will gives columns present in the dataset, non null counts of data for each column and datatype of the each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193468 entries, 0 to 193467
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193468 non-null  int64
#  1   inning            193468 non-null  int64
#  2   over              193468 non-null  int64
#  3   ball              193468 non-null  int64
#  4   batsman           193468 non-null  object
#  5   non_striker       193468 non-null  object
#  6   bowler            193468 non-null  object
#  7   batsman_runs      193468 non-null  int64
#  8   extra_runs        193468 non-null  int64
#  9   total_runs        193468 non-null  int64
#  10  is_wicket         193468 non-null  int64
#  11  dismissal_kind    9495 non-null    object
#  12  player_dismissed  9495 non-null    object
#  13  fielder           6784 non-null    object
#  14  extras_type       10233 non-null   object
#  15  batting_team      193468 non-null  object
# ...

# %%
# DataFrame.dtypes function will gives the datatype of each column present in the dataset.
df.dtypes
# Out:
# id                   int64
# inning               int64
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# is_wicket            int64
# dismissal_kind      object
# player_dismissed    object
# fielder             object
# extras_type         object
# batting_team        object
# bowling_team        object
# dtype: object

# %%
# To slice more than 1 column from the dataset, this will not work.
df['batsman','non_striker']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('batsman', 'non_striker')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# To slice more than one column of dataset, we need to pass list inside the slicing operation
df[['batsman','non_striker','bowler']]
# df[['batsman','bowler']]
# Out:
#              batsman   non_striker    bowler
# 0         SC Ganguly   BB McCullum   P Kumar
# 1        BB McCullum    SC Ganguly   P Kumar
# 2        BB McCullum    SC Ganguly   P Kumar
# 3        BB McCullum    SC Ganguly   P Kumar
# 4        BB McCullum    SC Ganguly   P Kumar
# ...              ...           ...       ...
# 193463     HH Pandya  Ishan Kishan  K Rabada
# 193464     HH Pandya  Ishan Kishan  A Nortje
# 193465  Ishan Kishan     HH Pandya  A Nortje
# 193466     HH Pandya  Ishan Kishan  A Nortje
# 193467     KH Pandya  Ishan Kishan  A Nortje
#
# [193468 rows x 3 columns]

# %%
# If we pass single column inside list, that also works 
df[['batsman']]
# Out:
#              batsman
# 0         SC Ganguly
# 1        BB McCullum
# 2        BB McCullum
# 3        BB McCullum
# 4        BB McCullum
# ...              ...
# 193463     HH Pandya
# 193464     HH Pandya
# 193465  Ishan Kishan
# 193466     HH Pandya
# 193467     KH Pandya
#
# [193468 rows x 1 columns]

# %% [markdown]
# Type of the column of the dataframe, generally type of the any column is series, but if you pass it is inside the list, it will retrive data in the form of dataframe

# %%
type(df[['batsman']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Datafrme.describe() function wil gives fundamental statistics of every numerical column of the dataframe
df.describe()
# Out:
#                  id         inning           over           ball  \
# count  1.934680e+05  193468.000000  193468.000000  193468.000000
# mean   7.567688e+05       1.482131       9.177027       3.615967
# std    3.060971e+05       0.499682       5.676848       1.807128
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012270e+05       1.000000       4.000000       2.000000
# 50%    7.292970e+05       1.000000       9.000000       4.000000
# 75%    1.082628e+06       2.000000      14.000000       5.000000
# max    1.237181e+06       2.000000      19.000000       9.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  193468.000000  193468.000000  193468.000000  193468.000000
# mean        1.240231       0.066414       1.306645       0.049078
# std         1.610867       0.339991       1.598802       0.216031
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# If you want it for all the columns including numberical columns as well as object
df.describe(include = 'all')
# Out:
#                   id         inning           over           ball  batsman  \
# count   1.934680e+05  193468.000000  193468.000000  193468.000000   193468
# unique           NaN            NaN            NaN            NaN      537
# top              NaN            NaN            NaN            NaN  V Kohli
# freq             NaN            NaN            NaN            NaN     4609
# mean    7.567688e+05       1.482131       9.177027       3.615967      NaN
# std     3.060971e+05       0.499682       5.676848       1.807128      NaN
# min     3.359820e+05       1.000000       0.000000       1.000000      NaN
# 25%     5.012270e+05       1.000000       4.000000       2.000000      NaN
# 50%     7.292970e+05       1.000000       9.000000       4.000000      NaN
# 75%     1.082628e+06       2.000000      14.000000       5.000000      NaN
# max     1.237181e+06       2.000000      19.000000       9.000000      NaN
#
#        non_striker           bowler   batsman_runs     extra_runs  \
# ...

# %%
# The following command will give you True if the column is of object type otherwise false
df.dtypes == 'object'
# Out:
# id                  False
# inning              False
# over                False
# ball                False
# batsman              True
# non_striker          True
# bowler               True
# batsman_runs        False
# extra_runs          False
# total_runs          False
# is_wicket           False
# dismissal_kind       True
# player_dismissed     True
# fielder              True
# extras_type          True
# batting_team         True
# bowling_team         True
# dtype: bool

# %%
# To retrive the columns which are of the object type
df.dtypes[df.dtypes == 'object']
# Out:
# batsman             object
# non_striker         object
# bowler              object
# dismissal_kind      object
# player_dismissed    object
# fielder             object
# extras_type         object
# batting_team        object
# bowling_team        object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
# To retrive all the column names of the object type
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['batsman', 'non_striker', 'bowler', 'dismissal_kind',
#        'player_dismissed', 'fielder', 'extras_type', 'batting_team',
#        'bowling_team'],
#       dtype='object')

# %%
# To retrive the data of the object type columns of dataset
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#              batsman   non_striker    bowler dismissal_kind player_dismissed  \
# 0         SC Ganguly   BB McCullum   P Kumar            NaN              NaN
# 1        BB McCullum    SC Ganguly   P Kumar            NaN              NaN
# 2        BB McCullum    SC Ganguly   P Kumar            NaN              NaN
# 3        BB McCullum    SC Ganguly   P Kumar            NaN              NaN
# 4        BB McCullum    SC Ganguly   P Kumar            NaN              NaN
# ...              ...           ...       ...            ...              ...
# 193463     HH Pandya  Ishan Kishan  K Rabada            NaN              NaN
# 193464     HH Pandya  Ishan Kishan  A Nortje            NaN              NaN
# 193465  Ishan Kishan     HH Pandya  A Nortje            NaN              NaN
# 193466     HH Pandya  Ishan Kishan  A Nortje         caught        HH Pandya
# 193467     KH Pandya  Ishan Kishan  A Nortje            NaN              NaN
#
# ...

# %%
# Fundamental statistics of the all the object type of columns
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#         batsman non_striker           bowler dismissal_kind player_dismissed  \
# count    193468      193468           193468           9495             9495
# unique      537         530              420              9              506
# top     V Kohli    S Dhawan  Harbhajan Singh         caught        RG Sharma
# freq       4609        4593             3451           5743              167
#
#          fielder extras_type    batting_team    bowling_team
# count       6784       10233          193468          193277
# unique       879           5              15              15
# top     MS Dhoni       wides  Mumbai Indians  Mumbai Indians
# freq         164        5858           24466           24453

# %%
# This is same as the slcing operation
df.batsman
# Out:
# 0           SC Ganguly
# 1          BB McCullum
# 2          BB McCullum
# 3          BB McCullum
# 4          BB McCullum
#               ...
# 193463       HH Pandya
# 193464       HH Pandya
# 193465    Ishan Kishan
# 193466       HH Pandya
# 193467       KH Pandya
# Name: batsman, Length: 193468, dtype: object

# %%
df['batsman'][1:5]
# Out:
# 1    BB McCullum
# 2    BB McCullum
# 3    BB McCullum
# 4    BB McCullum
# Name: batsman, dtype: object

# %%
df['batsman'][1:10:2]
# Out:
# 1    BB McCullum
# 3    BB McCullum
# 5    BB McCullum
# 7    BB McCullum
# 9    BB McCullum
# Name: batsman, dtype: object

# %%
df['bowler_1'] = 'vish'

# %%
df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'bowler_1'],
#       dtype='object')

# %%
df.bowler.isnull()
#df['bowler'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 193463    False
# 193464    False
# 193465    False
# 193466    False
# 193467    False
# Name: bowler, Length: 193468, dtype: bool

# %%
df.isnull().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# bowler_1                 0
# dtype: int64

# %%
df.dropna()
# Out:
#              id  inning  over  ball           batsman       non_striker  \
# 6670     336010       1     8     6         DJ Hussey           T Taibu
# 9022     336020       1    15     2         G Gambhir          S Dhawan
# 21696    392217       2    16     6         ML Hayden       S Badrinath
# 21916    392218       2    13     2  RE van der Merwe        MV Boucher
# 22797    392222       1    17     6            K Goel         PP Chawla
# 24376    392228       2    17     1         A Symonds         RG Sharma
# 29235    419114       2     8     5        KD Karthik       MF Maharoof
# 38540    419153       1     4     1         DJ Hussey         MK Tiwary
# 40054    419159       2     4     1           M Vijay          SK Raina
# 40794    419162       2     6     2      KP Pietersen          R Dravid
# 42401    501201       1    16     4          UT Yadav  RE van der Merwe
# 46476    501219       2    16     6         MK Tiwary          R Bhatia
# ...

# %%
df.isnull().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# bowler_1                 0
# dtype: int64

# %%
df.shape
# Out:
# (193468, 18)

# %%
df['dismissal_kind'].isnull()
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 193463     True
# 193464     True
# 193465     True
# 193466    False
# 193467     True
# Name: dismissal_kind, Length: 193468, dtype: bool

# %%
df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'bowler_1'],
#       dtype='object')

# %%
df[df['batsman_runs'] == max(df['batsman_runs'])]
# Out:
#              id  inning  over  ball       batsman  non_striker      bowler  \
# 10       335982       1     1     4   BB McCullum   SC Ganguly      Z Khan
# 20       335982       1     3     2   BB McCullum   SC Ganguly   AA Noffke
# 25       335982       1     3     7   BB McCullum   SC Ganguly   AA Noffke
# 60       335982       1     9     5   BB McCullum   RT Ponting    SB Joshi
# 65       335982       1    10     4    RT Ponting  BB McCullum   JH Kallis
# ...         ...     ...   ...   ...           ...          ...         ...
# 193379  1237181       2     3     6     RG Sharma    Q de Kock    A Nortje
# 193382  1237181       2     4     3      SA Yadav    RG Sharma  MP Stoinis
# 193406  1237181       2     8     3     RG Sharma     SA Yadav     P Dubey
# 193408  1237181       2     8     5     RG Sharma     SA Yadav     P Dubey
# 193443  1237181       2    14     4  Ishan Kishan    RG Sharma  MP Stoinis
#
# ...

# %%
df['batsman_runs'].unique()
# Out:
# array([0, 4, 6, 1, 2, 5, 3], dtype=int64)

# %%
df['total_runs'].unique()
# Out:
# array([1, 0, 4, 6, 5, 2, 3, 7], dtype=int64)

# %%
df[df['batsman'] == 'Ishan Kishan']
# Out:
#              id  inning  over  ball       batsman non_striker      bowler  \
# 123066   980905       2    14     4  Ishan Kishan  KD Karthik  MG Johnson
# 123069   980905       2    15     1  Ishan Kishan  KD Karthik      P Sahu
# 123072   980905       2    15     4  Ishan Kishan  KD Karthik      P Sahu
# 123073   980905       2    15     5  Ishan Kishan  KD Karthik      P Sahu
# 123074   980905       2    15     6  Ishan Kishan  KD Karthik      P Sahu
# ...         ...     ...   ...   ...           ...         ...         ...
# 193449  1237181       2    15     4  Ishan Kishan   RG Sharma     P Dubey
# 193454  1237181       2    16     3  Ishan Kishan  KA Pollard    A Nortje
# 193460  1237181       2    17     3  Ishan Kishan   HH Pandya    K Rabada
# 193461  1237181       2    17     4  Ishan Kishan   HH Pandya    K Rabada
# 193465  1237181       2    18     2  Ishan Kishan   HH Pandya    A Nortje
#
#         batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# ...

# %%
len(df[df['batsman'] == 'Ishan Kishan'])
# Out:
# 907

# %%
df[df['batting_team'] == 'Mumbai Indians']
# Out:
#              id  inning  over  ball       batsman    non_striker    bowler  \
# 692      335985       1     0     1      L Ronchi  ST Jayasuriya   P Kumar
# 693      335985       1     0     2      L Ronchi  ST Jayasuriya   P Kumar
# 694      335985       1     0     3      L Ronchi  ST Jayasuriya   P Kumar
# 695      335985       1     0     4      L Ronchi  ST Jayasuriya   P Kumar
# 696      335985       1     0     5      L Ronchi  ST Jayasuriya   P Kumar
# ...         ...     ...   ...   ...           ...            ...       ...
# 193463  1237181       2    17     6     HH Pandya   Ishan Kishan  K Rabada
# 193464  1237181       2    18     1     HH Pandya   Ishan Kishan  A Nortje
# 193465  1237181       2    18     2  Ishan Kishan      HH Pandya  A Nortje
# 193466  1237181       2    18     3     HH Pandya   Ishan Kishan  A Nortje
# 193467  1237181       2    18     4     KH Pandya   Ishan Kishan  A Nortje
#
# ...

# %%
#retriving the data of batsman who scored more than 4 runs over a single delivery
df[df['batsman_runs'] > 4]['batsman']
# Out:
# 10         BB McCullum
# 20         BB McCullum
# 25         BB McCullum
# 60         BB McCullum
# 65          RT Ponting
#               ...
# 193379       RG Sharma
# 193382        SA Yadav
# 193406       RG Sharma
# 193408       RG Sharma
# 193443    Ishan Kishan
# Name: batsman, Length: 8962, dtype: object

# %%
df[(df['total_runs'] > 4) & (df['total_runs'] > 5)]
# Out:
#              id  inning  over  ball       batsman  non_striker      bowler  \
# 10       335982       1     1     4   BB McCullum   SC Ganguly      Z Khan
# 20       335982       1     3     2   BB McCullum   SC Ganguly   AA Noffke
# 25       335982       1     3     7   BB McCullum   SC Ganguly   AA Noffke
# 60       335982       1     9     5   BB McCullum   RT Ponting    SB Joshi
# 65       335982       1    10     4    RT Ponting  BB McCullum   JH Kallis
# ...         ...     ...   ...   ...           ...          ...         ...
# 193379  1237181       2     3     6     RG Sharma    Q de Kock    A Nortje
# 193382  1237181       2     4     3      SA Yadav    RG Sharma  MP Stoinis
# 193406  1237181       2     8     3     RG Sharma     SA Yadav     P Dubey
# 193408  1237181       2     8     5     RG Sharma     SA Yadav     P Dubey
# 193443  1237181       2    14     4  Ishan Kishan    RG Sharma  MP Stoinis
#
# ...

# %%
df1 = pd.read_excel("D:\Power Bi\Datasets\Sample - Superstore.xlsx")
df1.head()
# Out:
# C:\Users\svish\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# ...

# %%
df1.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %% [raw]
# date = pd.to_datetime(df['column_name'])
# type(date)
#
# type(date[0])
#
# df['coverted_date'] = pd.to_datetime(df['column_name'])
# df
#
# df['converted_year'] = pd.to_datetime(df['column_name']).dt.year
# df.head()
#
# df['converted_month'] = pd.to_datetime(df['column_name']).dt.month
# df.head()
#
# df['converted_week'] = pd.to_datetime(df['column_name']).dt.week
# df.head()

# %%
df1['Order Date']
# Out:
# 0      2018-11-08
# 1      2018-11-08
# 2      2018-06-12
# 3      2017-10-11
# 4      2017-10-11
#           ...
# 9989   2016-01-21
# 9990   2019-02-26
# 9991   2019-02-26
# 9992   2019-02-26
# 9993   2019-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
type(df1['Order Date'])
# Out:
# pandas.core.series.Series

# %%
df1['Order_date_year'] = df1['Order Date'].dt.year
df1.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11  Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11  Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16  Second Class    DV-13045
#
#      Customer Name    Segment Country/Region         City  ... Region  \
# 0      Claire Gute   Consumer  United States    Henderson  ...  South
# 1      Claire Gute   Consumer  United States    Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...   West
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# ...

# %%
df1['Order_date_Month'] = df1['Order Date'].dt.month
df1.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11  Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11  Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16  Second Class    DV-13045
#
#      Customer Name    Segment Country/Region         City  ...  \
# 0      Claire Gute   Consumer  United States    Henderson  ...
# 1      Claire Gute   Consumer  United States    Henderson  ...
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# ...

# %%
df1['Order_date_Week'] = df1['Order Date'].dt.weekofyear
df1.head(3)
# Out:
# C:\Users\svish\AppData\Local\Temp/ipykernel_16840/3243095616.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df1['Order_date_Week'] = df1['Order Date'].dt.weekofyear
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11  Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11  Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16  Second Class    DV-13045
#
#      Customer Name    Segment Country/Region         City  ...  \
# 0      Claire Gute   Consumer  United States    Henderson  ...
# 1      Claire Gute   Consumer  United States    Henderson  ...
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# 2  Office Supplies        Labels
#
# ...

# %%
df1[df1['Order_date_year'] == 2018]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 13        14  CA-2018-161389 2018-12-05 2018-12-10  Standard Class
# 21        22  CA-2018-137330 2018-12-09 2018-12-13  Standard Class
# ...      ...             ...        ...        ...             ...
# 9978    9979  US-2018-103674 2018-12-06 2018-12-10  Standard Class
# 9979    9980  US-2018-103674 2018-12-06 2018-12-10  Standard Class
# 9982    9983  US-2018-157728 2018-09-22 2018-09-28  Standard Class
# 9983    9984  US-2018-157728 2018-09-22 2018-09-28  Standard Class
# 9986    9987  CA-2018-125794 2018-09-29 2018-10-03  Standard Class
#
#      Customer ID    Customer Name      Segment Country/Region          City  \
# 0       CG-12520      Claire Gute     Consumer  United States     Henderson
# ...

# %%
df1['Order_date_Month'].value_counts()
# Out:
# 11    1471
# 12    1408
# 9     1383
# 10     819
# 5      735
# 6      717
# 7      710
# 8      706
# 3      696
# 4      668
# 1      381
# 2      300
# Name: Order_date_Month, dtype: int64

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Order_date_year', 'Order_date_Month', 'Order_date_Week'],
#       dtype='object')

# %%
# df['Cost'] = df['discount']+d['shipment_cost']

# %%
# df[df['cost'] == max(df[cost])]['product_name']

# %%
df1.drop('Order_date_Month')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16840/671211573.py in <module>
# ----> 1 df1.drop('Order_date_Month')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df1.drop('Order_date_Month',axis = 1)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df1.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
df1.drop('Order_date_Month',axis = 1,inplace = True)

# %%
df1.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
df1 = df1.drop('Order_date_year',axis = 1)

# %%
df1.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df1['year'] = df1['Order Date'].dt.year

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Order_date_Week', 'year'],
#       dtype='object')

# %%
df1 = df1.drop(columns = ['Order_date_Week','year'])

# %%
df1.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df1.loc[[2,3]]
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
#
#                                         Product Name     Sales  Quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
#
#    Discount    Profit
# 2      0.00    6.8714
# 3      0.45 -383.0310
#
# [2 rows x 21 columns]

# %%
df1[3:9]
#df1.loc[2:10]
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 5       6  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
# 6       7  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
# 7       8  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
# 8       9  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
#
#      Customer Name   Segment Country/Region             City  ... Postal Code  \
# 3   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...     33311.0
# 4   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...     33311.0
# 5  Brosina Hoffman  Consumer  United States      Los Angeles  ...     90032.0
# 6  Brosina Hoffman  Consumer  United States      Los Angeles  ...     90032.0
# ...

# %%
df1[2:10:2]
#df1.loc[2:10:2]
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 6       7  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
# 8       9  CA-2016-115812 2016-06-09 2016-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment Country/Region             City  ...  \
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
# ...

# %%
df1.loc[0:4,['Order Date','Ship Date']]
# Out:
#   Order Date  Ship Date
# 0 2018-11-08 2018-11-11
# 1 2018-11-08 2018-11-11
# 2 2018-06-12 2018-06-16
# 3 2017-10-11 2017-10-18
# 4 2017-10-11 2017-10-18

# %%
#df.loc[0:4,2:4]

# %%
df1.iloc[0:4,2:4]
# Out:
#   Order Date  Ship Date
# 0 2018-11-08 2018-11-11
# 1 2018-11-08 2018-11-11
# 2 2018-06-12 2018-06-16
# 3 2017-10-11 2017-10-18

# %% [raw]
# df.loc only work with named indexes.
# df.iloc works with defualt internal indexes ( 0, 1,2,3 ..... )

# %%
#df1.iloc['Row','column']
df1.iloc[2:5,2:4]
# Out:
#   Order Date  Ship Date
# 2 2018-06-12 2018-06-16
# 3 2017-10-11 2017-10-18
# 4 2017-10-11 2017-10-18

# %%
df.iloc[:5]
# Out:
#        id  inning  over  ball      batsman  non_striker   bowler  \
# 0  335982       1     0     1   SC Ganguly  BB McCullum  P Kumar
# 1  335982       1     0     2  BB McCullum   SC Ganguly  P Kumar
# 2  335982       1     0     3  BB McCullum   SC Ganguly  P Kumar
# 3  335982       1     0     4  BB McCullum   SC Ganguly  P Kumar
# 4  335982       1     0     5  BB McCullum   SC Ganguly  P Kumar
#
#    batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# 0             0           1           1          0            NaN
# 1             0           0           0          0            NaN
# 2             0           1           1          0            NaN
# 3             0           0           0          0            NaN
# 4             0           0           0          0            NaN
#
#   player_dismissed fielder extras_type           batting_team  \
# 0              NaN     NaN     legbyes  Kolkata Knight Riders
# ...

# %%
df.iloc[2:10:2]
# Out:
#        id  inning  over  ball      batsman non_striker   bowler  batsman_runs  \
# 2  335982       1     0     3  BB McCullum  SC Ganguly  P Kumar             0
# 4  335982       1     0     5  BB McCullum  SC Ganguly  P Kumar             0
# 6  335982       1     0     7  BB McCullum  SC Ganguly  P Kumar             0
# 8  335982       1     1     2  BB McCullum  SC Ganguly   Z Khan             4
#
#    extra_runs  total_runs  is_wicket dismissal_kind player_dismissed fielder  \
# 2           1           1          0            NaN              NaN     NaN
# 4           0           0          0            NaN              NaN     NaN
# 6           1           1          0            NaN              NaN     NaN
# 8           0           4          0            NaN              NaN     NaN
#
#   extras_type           batting_team                 bowling_team bowler_1
# 2       wides  Kolkata Knight Riders  Royal Challengers Bangalore     vish
# ...

# %%
df1.dtypes[(df1.dtypes == 'float64')| (df.dtypes == 'int64')]
# Out:
# Postal Code    float64
# Sales          float64
# Discount       float64
# Profit         float64
# dtype: object

# %%
df.dtypes[df.dtypes != 'object']
# Out:
# id              int64
# inning          int64
# over            int64
# ball            int64
# batsman_runs    int64
# extra_runs      int64
# total_runs      int64
# is_wicket       int64
# dtype: object

# %%
df1.dtypes[(df1.dtypes == 'float64')| (df.dtypes == 'int64')].index
# Out:
# Index(['Postal Code', 'Sales', 'Discount', 'Profit'], dtype='object')

# %%
df2 = df1[df1.dtypes[(df1.dtypes == 'float64')| (df.dtypes == 'int64')].index]

# %%
df.dtypes[df.dtypes != 'object'].index
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman_runs', 'extra_runs',
#        'total_runs', 'is_wicket'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes != 'object'].index]
# Out:
#              id  inning  over  ball  batsman_runs  extra_runs  total_runs  \
# 0        335982       1     0     1             0           1           1
# 1        335982       1     0     2             0           0           0
# 2        335982       1     0     3             0           1           1
# 3        335982       1     0     4             0           0           0
# 4        335982       1     0     5             0           0           0
# ...         ...     ...   ...   ...           ...         ...         ...
# 193463  1237181       2    17     6             1           0           1
# 193464  1237181       2    18     1             1           0           1
# 193465  1237181       2    18     2             1           0           1
# 193466  1237181       2    18     3             0           0           0
# 193467  1237181       2    18     4             1           0           1
#
#         is_wicket
# 0               0
# 1               0
# 2               0
# ...

# %%
df2[df2 > 100]
# Out:
#       Postal Code     Sales  Discount   Profit
# 0         42420.0  261.9600       NaN      NaN
# 1         42420.0  731.9400       NaN  219.582
# 2         90036.0       NaN       NaN      NaN
# 3         33311.0  957.5775       NaN      NaN
# 4         33311.0       NaN       NaN      NaN
# ...           ...       ...       ...      ...
# 9989      33180.0       NaN       NaN      NaN
# 9990      92627.0       NaN       NaN      NaN
# 9991      92627.0  258.5760       NaN      NaN
# 9992      92627.0       NaN       NaN      NaN
# 9993      92683.0  243.1600       NaN      NaN
#
# [9994 rows x 4 columns]

# %%
df3 = df2[df2 > 100]

# %%
df3
# Out:
#       Postal Code     Sales  Discount   Profit
# 0         42420.0  261.9600       NaN      NaN
# 1         42420.0  731.9400       NaN  219.582
# 2         90036.0       NaN       NaN      NaN
# 3         33311.0  957.5775       NaN      NaN
# 4         33311.0       NaN       NaN      NaN
# ...           ...       ...       ...      ...
# 9989      33180.0       NaN       NaN      NaN
# 9990      92627.0       NaN       NaN      NaN
# 9991      92627.0  258.5760       NaN      NaN
# 9992      92627.0       NaN       NaN      NaN
# 9993      92683.0  243.1600       NaN      NaN
#
# [9994 rows x 4 columns]

# %%
df3.dropna(inplace = True)

# %%
df3
# Out:
# Empty DataFrame
# Columns: [Postal Code, Sales, Discount, Profit]
# Index: []

# %%
df2.dropna(axis =1)
# Out:
#          Sales  Discount    Profit
# 0     261.9600      0.00   41.9136
# 1     731.9400      0.00  219.5820
# 2      14.6200      0.00    6.8714
# 3     957.5775      0.45 -383.0310
# 4      22.3680      0.20    2.5164
# ...        ...       ...       ...
# 9989   25.2480      0.20    4.1028
# 9990   91.9600      0.00   15.6332
# 9991  258.5760      0.20   19.3932
# 9992   29.6000      0.00   13.3200
# 9993  243.1600      0.00   72.9480
#
# [9994 rows x 3 columns]

# %%
df2
# Out:
#       Postal Code     Sales  Discount    Profit
# 0         42420.0  261.9600      0.00   41.9136
# 1         42420.0  731.9400      0.00  219.5820
# 2         90036.0   14.6200      0.00    6.8714
# 3         33311.0  957.5775      0.45 -383.0310
# 4         33311.0   22.3680      0.20    2.5164
# ...           ...       ...       ...       ...
# 9989      33180.0   25.2480      0.20    4.1028
# 9990      92627.0   91.9600      0.00   15.6332
# 9991      92627.0  258.5760      0.20   19.3932
# 9992      92627.0   29.6000      0.00   13.3200
# 9993      92683.0  243.1600      0.00   72.9480
#
# [9994 rows x 4 columns]

# %%
# To drop the rows having null values in it.
df2.dropna(thresh = 2)
# Out:
#       Postal Code     Sales  Discount    Profit
# 0         42420.0  261.9600      0.00   41.9136
# 1         42420.0  731.9400      0.00  219.5820
# 2         90036.0   14.6200      0.00    6.8714
# 3         33311.0  957.5775      0.45 -383.0310
# 4         33311.0   22.3680      0.20    2.5164
# ...           ...       ...       ...       ...
# 9989      33180.0   25.2480      0.20    4.1028
# 9990      92627.0   91.9600      0.00   15.6332
# 9991      92627.0  258.5760      0.20   19.3932
# 9992      92627.0   29.6000      0.00   13.3200
# 9993      92683.0  243.1600      0.00   72.9480
#
# [9994 rows x 4 columns]

# %%
df3 = df2[df2 > 100]
df3
# Out:
#       Postal Code     Sales  Discount   Profit
# 0         42420.0  261.9600       NaN      NaN
# 1         42420.0  731.9400       NaN  219.582
# 2         90036.0       NaN       NaN      NaN
# 3         33311.0  957.5775       NaN      NaN
# 4         33311.0       NaN       NaN      NaN
# ...           ...       ...       ...      ...
# 9989      33180.0       NaN       NaN      NaN
# 9990      92627.0       NaN       NaN      NaN
# 9991      92627.0  258.5760       NaN      NaN
# 9992      92627.0       NaN       NaN      NaN
# 9993      92683.0  243.1600       NaN      NaN
#
# [9994 rows x 4 columns]

# %%
df3.dropna(thresh = 3)
# Out:
#       Postal Code     Sales  Discount    Profit
# 1         42420.0   731.940       NaN  219.5820
# 13        98103.0   407.976       NaN  132.5922
# 24        84057.0  1044.630       NaN  240.2649
# 35        75080.0  1097.544       NaN  123.4737
# 54        10024.0  1029.950       NaN  298.6855
# ...           ...       ...       ...       ...
# 9947      46203.0  1925.880       NaN  539.2464
# 9948      46203.0  2405.200       NaN  793.7160
# 9957      10801.0   223.920       NaN  109.7208
# 9968       7060.0   735.980       NaN  331.1910
# 9979      90032.0   437.472       NaN  153.1152
#
# [885 rows x 4 columns]

# %%
df3.dropna(axis = 1,thresh = 2)
# Out:
#       Postal Code     Sales   Profit
# 0         42420.0  261.9600      NaN
# 1         42420.0  731.9400  219.582
# 2         90036.0       NaN      NaN
# 3         33311.0  957.5775      NaN
# 4         33311.0       NaN      NaN
# ...           ...       ...      ...
# 9989      33180.0       NaN      NaN
# 9990      92627.0       NaN      NaN
# 9991      92627.0  258.5760      NaN
# 9992      92627.0       NaN      NaN
# 9993      92683.0  243.1600      NaN
#
# [9994 rows x 3 columns]

# %%
#df3.fillna(value = 0.2,inplace = True)
df3.fillna(value = 0.2)
# Out:
#       Postal Code     Sales  Discount   Profit
# 0         42420.0  261.9600       0.2    0.200
# 1         42420.0  731.9400       0.2  219.582
# 2         90036.0    0.2000       0.2    0.200
# 3         33311.0  957.5775       0.2    0.200
# 4         33311.0    0.2000       0.2    0.200
# ...           ...       ...       ...      ...
# 9989      33180.0    0.2000       0.2    0.200
# 9990      92627.0    0.2000       0.2    0.200
# 9991      92627.0  258.5760       0.2    0.200
# 9992      92627.0    0.2000       0.2    0.200
# 9993      92683.0  243.1600       0.2    0.200
#
# [9994 rows x 4 columns]

# %%
df3.fillna(value = df3['Profit'].mean())
# Out:
#       Postal Code      Sales   Discount     Profit
# 0         42420.0  261.96000  337.27534  337.27534
# 1         42420.0  731.94000  337.27534  219.58200
# 2         90036.0  337.27534  337.27534  337.27534
# 3         33311.0  957.57750  337.27534  337.27534
# 4         33311.0  337.27534  337.27534  337.27534
# ...           ...        ...        ...        ...
# 9989      33180.0  337.27534  337.27534  337.27534
# 9990      92627.0  337.27534  337.27534  337.27534
# 9991      92627.0  258.57600  337.27534  337.27534
# 9992      92627.0  337.27534  337.27534  337.27534
# 9993      92683.0  243.16000  337.27534  337.27534
#
# [9994 rows x 4 columns]

# %%
df3.fillna(value = df3['Profit'].min())
# Out:
#       Postal Code     Sales  Discount   Profit
# 0         42420.0  261.9600   100.122  100.122
# 1         42420.0  731.9400   100.122  219.582
# 2         90036.0  100.1220   100.122  100.122
# 3         33311.0  957.5775   100.122  100.122
# 4         33311.0  100.1220   100.122  100.122
# ...           ...       ...       ...      ...
# 9989      33180.0  100.1220   100.122  100.122
# 9990      92627.0  100.1220   100.122  100.122
# 9991      92627.0  258.5760   100.122  100.122
# 9992      92627.0  100.1220   100.122  100.122
# 9993      92683.0  243.1600   100.122  100.122
#
# [9994 rows x 4 columns]

# %%
df1
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df
# Out:
#              id  inning  over  ball       batsman   non_striker    bowler  \
# 0        335982       1     0     1    SC Ganguly   BB McCullum   P Kumar
# 1        335982       1     0     2   BB McCullum    SC Ganguly   P Kumar
# 2        335982       1     0     3   BB McCullum    SC Ganguly   P Kumar
# 3        335982       1     0     4   BB McCullum    SC Ganguly   P Kumar
# 4        335982       1     0     5   BB McCullum    SC Ganguly   P Kumar
# ...         ...     ...   ...   ...           ...           ...       ...
# 193463  1237181       2    17     6     HH Pandya  Ishan Kishan  K Rabada
# 193464  1237181       2    18     1     HH Pandya  Ishan Kishan  A Nortje
# 193465  1237181       2    18     2  Ishan Kishan     HH Pandya  A Nortje
# 193466  1237181       2    18     3     HH Pandya  Ishan Kishan  A Nortje
# 193467  1237181       2    18     4     KH Pandya  Ishan Kishan  A Nortje
#
#         batsman_runs  extra_runs  total_runs  is_wicket dismissal_kind  \
# ...

# %%
df1.groupby(df1['Order Date'].dt.year)['Profit'].mean()
# Out:
# Order Date
# 2016    24.858994
# 2017    29.314274
# 2018    31.617771
# 2019    28.212340
# Name: Profit, dtype: float64

# %%
df1.groupby(df1['Order Date'].dt.month)['Profit'].mean()
# Out:
# Order Date
# 1     23.974924
# 2     34.315369
# 3     41.084321
# 4     17.346462
# 5     30.491575
# 6     29.687302
# 7     19.482626
# 8     30.845522
# 9     26.650380
# 10    38.808353
# 11    24.111779
# 12    30.801983
# Name: Profit, dtype: float64

# %%
df1.groupby(df1['Order Date'].dt.year)['Sales'].mean()
# Out:
# Order Date
# 2016    242.974159
# 2017    223.849909
# 2018    235.487282
# 2019    221.381418
# Name: Sales, dtype: float64

# %%
df1.groupby(df1['Order Date'].dt.month)['Sales'].mean()
# Out:
# Order Date
# 1     249.146550
# 2     199.170838
# 3     294.548116
# 4     206.230731
# 5     210.923553
# 6     212.996763
# 7     207.377601
# 8     225.274877
# 9     222.451154
# 10    244.594609
# 11    239.606438
# 12    231.032318
# Name: Sales, dtype: float64

# %%
df1.groupby('Category')['Sales'].mean()
# Out:
# Category
# Furniture          349.834887
# Office Supplies    119.324101
# Technology         452.709276
# Name: Sales, dtype: float64

# %%
df1.groupby('Sub-Category')['Sales'].mean()
# Out:
# Sub-Category
# Accessories     215.974604
# Appliances      230.755710
# Art              34.068834
# Binders         133.560560
# Bookcases       503.859633
# Chairs          532.332420
# Copiers        2198.941618
# Envelopes        64.867724
# Fasteners        13.936774
# Furnishings      95.825668
# Labels           34.303055
# Machines       1645.553313
# Paper            57.284092
# Phones          371.211534
# Storage         264.590553
# Supplies        245.650200
# Tables          648.794771
# Name: Sales, dtype: float64

# %%
# df['column'] = df['column'].str.replace(',','').astype(int)

# %%
df1.groupby(df1['Order Date'].dt.year)['Quantity'].max()
# Out:
# Order Date
# 2016    14
# 2017    14
# 2018    14
# 2019    14
# Name: Quantity, dtype: int64

# %%
df1.groupby(df1['Order Date'].dt.year)['Quantity'].sum()
# Out:
# Order Date
# 2016     7581
# 2017     7979
# 2018     9837
# 2019    12476
# Name: Quantity, dtype: int64

# %%
df1.groupby(df1['Segment'])['Profit'].mean()
# Out:
# Segment
# Consumer       25.836873
# Corporate      30.456667
# Home Office    33.818664
# Name: Profit, dtype: float64

# %% [raw]
# 1. Find out there average rating on weekly basis,keep in mind they take two days of leave on weekly basis.
# 2. Total working days each agents.
# 3. Total query that has been taken by any agent.
# 4. Total feedback that the agent has been received
# 5. a names who have average rating between 3.5 to 4.
# 6. Agent name who has rating less than 3.5
# 7. Agent name who has rating more than 4.5
# 8. How many feedback agents have received more than 4.5 average.
# 9. Average weekly response time for each agent.
# 10. Average weekly resoltion time for each agents.
# 11. list of all agent names.
# 12. Percentage of chat on which they received feedback.
# 13. Total contribution hour for each and every agent weekly basis.
# 14. Total percentage of active hour for a month.
